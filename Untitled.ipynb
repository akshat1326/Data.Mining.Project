# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import csv
import pylab as pl
from sklearn.cluster import DBSCAN
from collections import Counter
import colorsys
import import_ipynb
import Dbscan
from tqdm import tqdm
# Out:
# importing Jupyter notebook from Dbscan.ipynb

# %%
#Reading Dataset through list
with open('../Data/BASIC_HABITATION_INFORMATION_AS_ON_1_APR_09.csv',"r") as f:
    reader = csv.reader(f,delimiter = ",")
    print(reader)
    data = list(reader)
    row_count = len(data)

#converting list to dataframe
column_name = data.pop(0) 
column_name.insert(17,"temp")
df=pd.DataFrame(data,columns=column_name)
df.drop(columns=['temp'],inplace = True)
df.rename(columns={"SC Current Population":"SC Current Population 2009","ST Current Population":"ST Current Population 2009","GENERAL Current Population":"GENERAL Current Population 2009"},inplace =True)
df.rename(columns={"SC Covered Population":"SC Covered Population 2009","ST Covered Population":"ST Covered Population 2009","GENERAL Covered Population":"GENERAL Covered Population 2009"},inplace =True)

with open('../Data/BASIC_HABITATION_INFORMATION_AS_ON_1_APR_10.csv',"r") as f:
    reader = csv.reader(f,delimiter = ",")
    print(reader)
    data1 = list(reader)
    row_count = len(data1)

column_name = data1.pop(0) 
column_name.insert(17,"temp")
df1=pd.DataFrame(data,columns=column_name)
df1.drop(columns=['temp'],inplace = True)
df1.rename(columns={"SC Current Population":"SC Current Population 2010","ST Current Population":"ST Current Population 2010","GENERAL Current Population":"GENERAL Current Population 2010"},inplace =True)
df1.rename(columns={"SC Covered Population":"SC Covered Population 2010","ST Covered Population":"ST Covered Population 2010","GENERAL Covered Population":"GENERAL Covered Population 2010"},inplace =True)

with open('../Data/BASIC_HABITATION_INFORMATION_AS_ON_1_APR_11.csv',"r") as f:
    reader = csv.reader(f,delimiter = ",")
    print(reader)
    data2 = list(reader)
    row_count = len(data2)

column_name = data2.pop(0) 
column_name.insert(17,"temp")
df2=pd.DataFrame(data,columns=column_name)
df2.drop(columns=['temp'],inplace = True)
df2.rename(columns={"SC Current Population":"SC Current Population 2011","ST Current Population":"ST Current Population 2011","GENERAL Current Population":"GENERAL Current Population 2011"},inplace =True)
df2.rename(columns={"SC Covered Population":"SC Covered Population 2011","ST Covered Population":"ST Covered Population 2011","GENERAL Covered Population":"GENERAL Covered Population 2011"},inplace =True)



with open('../Data/BASIC_HABITATION_INFORMATION_AS_ON_1_APR_12.csv',"r") as f:
    reader = csv.reader(f,delimiter = ",")
    print(reader)
    data3 = list(reader)
    row_count = len(data3)

column_name = data3.pop(0) 
column_name.insert(17,"temp")
df3=pd.DataFrame(data,columns=column_name)
df3.drop(columns=['temp'],inplace = True)
df3.rename(columns={"SC Current Population":"SC Current Population 2012","ST Current Population":"ST Current Population 2012","GENERAL Current Population":"GENERAL Current Population 2012"},inplace =True)
df3.rename(columns={"SC Covered Population":"SC Covered Population 2012","ST Covered Population":"ST Covered Population 2012","GENERAL Covered Population":"GENERAL Covered Population 2012"},inplace =True)

# %% [markdown]
# ## Preprocessing

# %%
#Dimension Reductiion(droping attributes)
df.drop(columns=['Year','Habitation Name'],inplace = True)
df.drop(columns=['Status','SC Concentrated','ST Concentrated'],inplace = True)
df1.drop(columns=['Year','Habitation Name'],inplace = True)
df1.drop(columns=['Status','SC Concentrated','ST Concentrated'],inplace = True)
df2.drop(columns=['Year','Habitation Name'],inplace = True)
df2.drop(columns=['Status','SC Concentrated','ST Concentrated'],inplace = True)
df3.drop(columns=['Year','Habitation Name'],inplace = True)
df3.drop(columns=['Status','SC Concentrated','ST Concentrated'],inplace = True)

# %%
#Removing duplicate enteries
df.drop_duplicates(inplace = True)
df1.drop_duplicates(inplace = True)
df2.drop_duplicates(inplace = True)
df3.drop_duplicates(inplace = True)

# %%
#Removing noise using regular expression
pattern = " AM$| PM$|^[0-9]$"
name_remove =' LADE"$'
filter = df['Village Name'].str.contains(pattern)
df = df[~filter]
filter1 = df1['Village Name'].str.contains(pattern)
df1 = df1[~filter1]
filter2 = df2['Village Name'].str.contains(pattern)
df2 = df2[~filter2]
filter3 = df3['Village Name'].str.contains(pattern)
df3 = df3[~filter3]
filter = df['SC Current Population 2009'].str.contains(name_remove)
df = df[~filter]
filter = df1['SC Current Population 2010'].str.contains(name_remove)
df1 = df1[~filter]
filter = df2['SC Current Population 2011'].str.contains(name_remove)
df2 = df2[~filter]
filter = df3['SC Current Population 2012'].str.contains(name_remove)
df3 = df3[~filter]

# %%
#Converting datatypes from string to float for further use
df['SC Current Population 2009']=df['SC Current Population 2009'].astype(str).astype(float)
df['ST Current Population 2009']=df['ST Current Population 2009'].astype(str).astype(float)
df['GENERAL Current Population 2009']=df['GENERAL Current Population 2009'].astype(str).astype(float)
df['SC Covered Population 2009']=df['SC Covered Population 2009'].astype(str).astype(float)
df['ST Covered Population 2009']=df['ST Covered Population 2009'].astype(str).astype(float)
df['GENERAL Covered Population 2009']=df['GENERAL Covered Population 2009'].astype(str).astype(float)

df1['SC Current Population 2010']=df1['SC Current Population 2010'].astype(str).astype(float)
df1['ST Current Population 2010']=df1['ST Current Population 2010'].astype(str).astype(float)
df1['GENERAL Current Population 2010']=df1['GENERAL Current Population 2010'].astype(str).astype(float)
df1['SC Covered Population 2010']=df1['SC Covered Population 2010'].astype(str).astype(float)
df1['ST Covered Population 2010']=df1['ST Covered Population 2010'].astype(str).astype(float)
df1['GENERAL Covered Population 2010']=df1['GENERAL Covered Population 2010'].astype(str).astype(float)

df2['SC Current Population 2011']=df2['SC Current Population 2011'].astype(str).astype(float)
df2['ST Current Population 2011']=df2['ST Current Population 2011'].astype(str).astype(float)
df2['GENERAL Current Population 2011']=df2['GENERAL Current Population 2011'].astype(str).astype(float)
df2['SC Covered Population 2011']=df2['SC Covered Population 2011'].astype(str).astype(float)
df2['ST Covered Population 2011']=df2['ST Covered Population 2011'].astype(str).astype(float)
df2['GENERAL Covered Population 2011']=df2['GENERAL Covered Population 2011'].astype(str).astype(float)

df3['SC Current Population 2012']=df3['SC Current Population 2012'].astype(str).astype(float)
df3['ST Current Population 2012']=df3['ST Current Population 2012'].astype(str).astype(float)
df3['GENERAL Current Population 2012']=df3['GENERAL Current Population 2012'].astype(str).astype(float)
df3['SC Covered Population 2012']=df3['SC Covered Population 2012'].astype(str).astype(float)
df3['ST Covered Population 2012']=df3['ST Covered Population 2012'].astype(str).astype(float)
df3['GENERAL Covered Population 2012']=df3['GENERAL Covered Population 2012'].astype(str).astype(float)

# %%
#searching for noise: if any population parameter is negative or total current population is zero

r,c = df.shape
noise = 0
for x in range(0,r):
  t1=df.iloc[x]['SC Current Population 2009']
  t2=df.iloc[x]['ST Current Population 2009']
  t3=df.iloc[x]['GENERAL Current Population 2009']
  t4=df.iloc[x]['SC Covered Population 2009']
  t5=df.iloc[x]['SC Covered Population 2009']
  t6=df.iloc[x]['GENERAL Covered Population 2009']
  sum1 = t1+t2+t3
  if(t1<0 or t2<0 or t3<0 or t4<0 or t5<0 or t6<0 or sum1==0):
    noise=noise+1
  if(x%10000==0):
    print(x)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000

# %%
check=0
x=0
while(check<noise):
  t1=df.iloc[x]['SC Current Population 2009']
  t2=df.iloc[x]['ST Current Population 2009']
  t3=df.iloc[x]['GENERAL Current Population 2009']
  t4=df.iloc[x]['SC Covered Population 2009']
  t5=df.iloc[x]['SC Covered Population 2009']
  t6=df.iloc[x]['GENERAL Covered Population 2009']
  sum1 = t1+t2+t3
  if(t1<0 or t2<0 or t3<0 or t4<0 or t5<0 or t6<0 or sum1==0):
    print("removing1 " ,x)
    df.drop(df.index[x], inplace = True)
    check=check+1
    x=x-1
  if(x%10000==0):
    print(x)
  x=x+1

# %%
check=0
x=0
while(check<noise):
  t1=df3.iloc[x]['SC Current Population 2012']
  t2=df3.iloc[x]['ST Current Population 2012']
  t3=df3.iloc[x]['GENERAL Current Population 2012']
  t4=df3.iloc[x]['SC Covered Population 2012']
  t5=df3.iloc[x]['SC Covered Population 2012']
  t6=df3.iloc[x]['GENERAL Covered Population 2012']
  sum1 = t1+t2+t3
  if(t1<0 or t2<0 or t3<0 or t4<0 or t5<0 or t6<0 or sum1==0):
    print("removing1 " ,x)
    df3.drop(df3.index[x], inplace = True)
    check=check+1
    x=x-1
  if(x%10000==0):
    print(x)
  x=x+1

# %%
check=0
x=0
while(check<noise):
  t1=df1.iloc[x]['SC Current Population 2010']
  t2=df1.iloc[x]['ST Current Population 2010']
  t3=df1.iloc[x]['GENERAL Current Population 2010']
  t4=df1.iloc[x]['SC Covered Population 2010']
  t5=df1.iloc[x]['SC Covered Population 2010']
  t6=df1.iloc[x]['GENERAL Covered Population 2010']
  sum1=t1+t2+t3
  if(t1<0 or t2<0 or t3<0 or t4<0 or t5<0 or t6<0 or sum1==0):
    print("removing1 " ,x)
    df1.drop(df.index[x], inplace = True)
    check=check+1
    x=x-1
  if(x%10000==0):
    print(x)
  x=x+1

# %%
check=0
x=0
while(check<noise):
  t1=df2.iloc[x]['SC Current Population 2011']
  t2=df2.iloc[x]['ST Current Population 2011']
  t3=df2.iloc[x]['GENERAL Current Population 2011']
  t4=df2.iloc[x]['SC Covered Population 2011']
  t5=df2.iloc[x]['SC Covered Population 2011']
  t6=df2.iloc[x]['GENERAL Covered Population 2011']
  sum1= t1+t2+t3
  if(t1<0 or t2<0 or t3<0 or t4<0 or t5<0 or t6<0 or sum1==0):
    print("removing1 " ,x)
    df2.drop(df.index[x], inplace = True)
    check=check+1
    x=x-1
  if(x%10000==0):
    print(x)
  x=x+1

# %% [markdown]
# ## Aggregation

# %%
#village level
village_level1 = df.groupby(['State Name','District Name', 'Block Name', 'Panchayat Name', 'Village Name'],as_index=False).agg({'GENERAL Current Population 2009': 'sum', 'GENERAL Covered Population 2009': 'sum', 'SC Current Population 2009': 'sum', 'SC Covered Population 2009': 'sum', 'ST Current Population 2009': 'sum', 'ST Covered Population 2009': 'sum'})
village_level2 = df1.groupby(['State Name','District Name', 'Block Name', 'Panchayat Name', 'Village Name'],as_index=False).agg({'GENERAL Current Population 2010': 'sum', 'GENERAL Covered Population 2010': 'sum', 'SC Current Population 2010': 'sum', 'SC Covered Population 2010': 'sum', 'ST Current Population 2010': 'sum', 'ST Covered Population 2010': 'sum'})
village_level3 = df2.groupby(['State Name','District Name', 'Block Name', 'Panchayat Name', 'Village Name'],as_index=False).agg({'GENERAL Current Population 2011': 'sum', 'GENERAL Covered Population 2011': 'sum', 'SC Current Population 2011': 'sum', 'SC Covered Population 2011': 'sum', 'ST Current Population 2011': 'sum', 'ST Covered Population 2011': 'sum'})
village_level4 = df3.groupby(['State Name','District Name', 'Block Name', 'Panchayat Name', 'Village Name'],as_index=False).agg({'GENERAL Current Population 2012': 'sum', 'GENERAL Covered Population 2012': 'sum', 'SC Current Population 2012': 'sum', 'SC Covered Population 2012': 'sum', 'ST Current Population 2012': 'sum', 'ST Covered Population 2012': 'sum'})

# %%
temp =pd.merge(village_level1,village_level2,on=['Village Name','State Name','District Name','Block Name','Panchayat Name'],sort = False)
temp1 =pd.merge(temp,village_level3,on=['Village Name','State Name','District Name','Block Name','Panchayat Name'],sort = False)
village_level =pd.merge(temp1,village_level4,on=['Village Name','State Name','District Name','Block Name','Panchayat Name'],sort = False)

# %%
noise=0
r,c=village_level.shape
for x in range(0,r):
  if(village_level.iloc[x]['SC Current Population 2009']<village_level.iloc[x]['SC Covered Population 2009']):
    print("removing1 ",x)
    noise=noise+1
    x=x-1
  elif(village_level.iloc[x]['ST Current Population 2009']<village_level.iloc[x]['ST Covered Population 2009']):
    print("removing1 ",x)
    noise=noise+1
    x=x-1
  elif(village_level.iloc[x]['GENERAL Current Population 2009']<village_level.iloc[x]['GENERAL Covered Population 2009']):
    print("removing1 ",x)
    x=x-1
    noise=noise+1
  if(x%10000==0):
    print(x)


x=0
check=0
while(check<noise):
  if(village_level.iloc[x]['SC Current Population 2009']<village_level.iloc[x]['SC Covered Population 2009']):
    print("removing1 ",x)
    village_level.drop(village_level.index[x], inplace = True)
    check = check+1
    x=x-1
  elif(village_level.iloc[x]['ST Current Population 2009']<village_level.iloc[x]['ST Covered Population 2009']):
    print("removing1 ",x)
    village_level.drop(village_level.index[x], inplace = True)
    check = check+1
    x=x-1
  elif(village_level.iloc[x]['GENERAL Current Population 2009']<village_level.iloc[x]['GENERAL Covered Population 2009']):
    print("removing1 ",x)
    village_level.drop(village_level.index[x], inplace = True)
    check=check+1
    x=x-1
  x=x+1
  if(x%10000==0):
    print(x)
  
village_level.to_csv('../Data/village_level_aggregation.csv')
level_temp =village_level

# %%
#panchayat level
level_temp.drop(columns =['Village Name'],inplace = True)
panchayat_level = level_temp.groupby(['State Name','District Name', 'Block Name', 'Panchayat Name'],as_index=False).agg({'GENERAL Current Population 2009': 'sum', 'GENERAL Covered Population 2009': 'sum', 'SC Current Population 2009': 'sum', 'SC Covered Population 2009': 'sum', 'ST Current Population 2009': 'sum', 'ST Covered Population 2009': 'sum','GENERAL Current Population 2010': 'sum', 'GENERAL Covered Population 2010': 'sum', 'SC Current Population 2010': 'sum', 'SC Covered Population 2010': 'sum', 'ST Current Population 2010': 'sum', 'ST Covered Population 2010': 'sum','GENERAL Current Population 2011': 'sum', 'GENERAL Covered Population 2011': 'sum', 'SC Current Population 2011': 'sum', 'SC Covered Population 2011': 'sum', 'ST Current Population 2011': 'sum', 'ST Covered Population 2011': 'sum','GENERAL Current Population 2012': 'sum', 'GENERAL Covered Population 2012': 'sum', 'SC Current Population 2012': 'sum', 'SC Covered Population 2012': 'sum', 'ST Current Population 2012': 'sum', 'ST Covered Population 2012': 'sum'})
panchayat_level.to_csv('../Data/panchayat_level_aggregation.csv')

# %%
#block level
level_temp.drop(columns =['Panchayat Name'],inplace = True)
block_level = level_temp.groupby(['State Name','District Name', 'Block Name'],as_index=False).agg({'GENERAL Current Population 2009': 'sum', 'GENERAL Covered Population 2009': 'sum', 'SC Current Population 2009': 'sum', 'SC Covered Population 2009': 'sum', 'ST Current Population 2009': 'sum', 'ST Covered Population 2009': 'sum','GENERAL Current Population 2010': 'sum', 'GENERAL Covered Population 2010': 'sum', 'SC Current Population 2010': 'sum', 'SC Covered Population 2010': 'sum', 'ST Current Population 2010': 'sum', 'ST Covered Population 2010': 'sum','GENERAL Current Population 2011': 'sum', 'GENERAL Covered Population 2011': 'sum', 'SC Current Population 2011': 'sum', 'SC Covered Population 2011': 'sum', 'ST Current Population 2011': 'sum', 'ST Covered Population 2011': 'sum','GENERAL Current Population 2012': 'sum', 'GENERAL Covered Population 2012': 'sum', 'SC Current Population 2012': 'sum', 'SC Covered Population 2012': 'sum', 'ST Current Population 2012': 'sum', 'ST Covered Population 2012': 'sum'})
block_level.to_csv('../Data/block_level_aggregation.csv')

# %%
#district level
level_temp.drop(columns =['Block Name'],inplace = True)
district_level = level_temp.groupby(['State Name','District Name'],as_index=False).agg({'GENERAL Current Population 2009': 'sum', 'GENERAL Covered Population 2009': 'sum', 'SC Current Population 2009': 'sum', 'SC Covered Population 2009': 'sum', 'ST Current Population 2009': 'sum', 'ST Covered Population 2009': 'sum','GENERAL Current Population 2010': 'sum', 'GENERAL Covered Population 2010': 'sum', 'SC Current Population 2010': 'sum', 'SC Covered Population 2010': 'sum', 'ST Current Population 2010': 'sum', 'ST Covered Population 2010': 'sum','GENERAL Current Population 2011': 'sum', 'GENERAL Covered Population 2011': 'sum', 'SC Current Population 2011': 'sum', 'SC Covered Population 2011': 'sum', 'ST Current Population 2011': 'sum', 'ST Covered Population 2011': 'sum','GENERAL Current Population 2012': 'sum', 'GENERAL Covered Population 2012': 'sum', 'SC Current Population 2012': 'sum', 'SC Covered Population 2012': 'sum', 'ST Current Population 2012': 'sum', 'ST Covered Population 2012': 'sum'})
district_level.to_csv('../Data/district_level_aggregation.csv')

# %%
#state level
level_temp.drop(columns =['District Name'],inplace = True)
state_level = level_temp.groupby(['State Name'],as_index=False).agg({'GENERAL Current Population 2009': 'sum', 'GENERAL Covered Population 2009': 'sum', 'SC Current Population 2009': 'sum', 'SC Covered Population 2009': 'sum', 'ST Current Population 2009': 'sum', 'ST Covered Population 2009': 'sum','GENERAL Current Population 2010': 'sum', 'GENERAL Covered Population 2010': 'sum', 'SC Current Population 2010': 'sum', 'SC Covered Population 2010': 'sum', 'ST Current Population 2010': 'sum', 'ST Covered Population 2010': 'sum','GENERAL Current Population 2011': 'sum', 'GENERAL Covered Population 2011': 'sum', 'SC Current Population 2011': 'sum', 'SC Covered Population 2011': 'sum', 'ST Current Population 2011': 'sum', 'ST Covered Population 2011': 'sum','GENERAL Current Population 2012': 'sum', 'GENERAL Covered Population 2012': 'sum', 'SC Current Population 2012': 'sum', 'SC Covered Population 2012': 'sum', 'ST Current Population 2012': 'sum', 'ST Covered Population 2012': 'sum'})
state_level.to_csv('../Data/state_level_aggregation.csv')

# %% [markdown]
# ## Attribute generation

# %%
#new attributes created using initial given attributes
state_level['Fraction of SC Covered Population 2009']=state_level['SC Covered Population 2009']/state_level['SC Current Population 2009']
state_level['Fraction of ST Covered Population 2009']=state_level['ST Covered Population 2009']/state_level['ST Current Population 2009']
state_level['Fraction of GENERAL Covered Population 2009']=state_level['GENERAL Covered Population 2009']/state_level['GENERAL Current Population 2009']
state_level['Fraction of SC/Total Population covered 2009' ]= state_level['SC Covered Population 2009']/(state_level['SC Covered Population 2009']+state_level['ST Covered Population 2009']+state_level['GENERAL Covered Population 2009'])
state_level['Fraction of ST/Total Population covered 2009' ]= state_level['ST Covered Population 2009']/(state_level['SC Covered Population 2009']+state_level['ST Covered Population 2009']+state_level['GENERAL Covered Population 2009'])
state_level['Fraction of GENERAL/Total Population covered 2009' ]= state_level['GENERAL Covered Population 2009']/(state_level['SC Covered Population 2009']+state_level['ST Covered Population 2009']+state_level['GENERAL Covered Population 2009'])
state_level['Fraction of SC Covered Population 2010']=state_level['SC Covered Population 2010']/state_level['SC Current Population 2010']
state_level['Fraction of ST Covered Population 2010']=state_level['ST Covered Population 2010']/state_level['ST Current Population 2010']
state_level['Fraction of GENERAL Covered Population 2010']=state_level['GENERAL Covered Population 2010']/state_level['GENERAL Current Population 2010']
state_level['Fraction of SC/Total Population covered 2010' ]= state_level['SC Covered Population 2010']/(state_level['SC Covered Population 2010']+state_level['ST Covered Population 2010']+state_level['GENERAL Covered Population 2010'])
state_level['Fraction of ST/Total Population covered 2010' ]= state_level['ST Covered Population 2010']/(state_level['SC Covered Population 2010']+state_level['ST Covered Population 2010']+state_level['GENERAL Covered Population 2010'])
state_level['Fraction of GENERAL/Total Population covered 2010' ]= state_level['GENERAL Covered Population 2010']/(state_level['SC Covered Population 2010']+state_level['ST Covered Population 2010']+state_level['GENERAL Covered Population 2010'])
state_level['Fraction of SC Covered Population 2011']=state_level['SC Covered Population 2011']/state_level['SC Current Population 2011']
state_level['Fraction of ST Covered Population 2011']=state_level['ST Covered Population 2011']/state_level['ST Current Population 2011']
state_level['Fraction of GENERAL Covered Population 2011']=state_level['GENERAL Covered Population 2011']/state_level['GENERAL Current Population 2012']
state_level['Fraction of SC/Total Population covered 2011' ]= state_level['SC Covered Population 2011']/(state_level['SC Covered Population 2011']+state_level['ST Covered Population 2011']+state_level['GENERAL Covered Population 2011'])
state_level['Fraction of ST/Total Population covered 2011' ]= state_level['ST Covered Population 2011']/(state_level['SC Covered Population 2011']+state_level['ST Covered Population 2011']+state_level['GENERAL Covered Population 2011'])
state_level['Fraction of GENERAL/Total Population covered 2011' ]= state_level['GENERAL Covered Population 2011']/(state_level['SC Covered Population 2011']+state_level['ST Covered Population 2011']+state_level['GENERAL Covered Population 2011'])
state_level['Fraction of SC Covered Population 2012']=state_level['SC Covered Population 2012']/state_level['SC Current Population 2012']
state_level['Fraction of ST Covered Population 2012']=state_level['ST Covered Population 2012']/state_level['ST Current Population 2012']
state_level['Fraction of GENERAL Covered Population 2012']=state_level['GENERAL Covered Population 2012']/state_level['GENERAL Current Population 2012']
state_level['Fraction of SC/Total Population covered 2012' ]= state_level['SC Covered Population 2012']/(state_level['SC Covered Population 2012']+state_level['ST Covered Population 2012']+state_level['GENERAL Covered Population 2012'])
state_level['Fraction of ST/Total Population covered 2012' ]= state_level['ST Covered Population 2012']/(state_level['SC Covered Population 2012']+state_level['ST Covered Population 2012']+state_level['GENERAL Covered Population 2012'])
state_level['Fraction of GENERAL/Total Population covered 2012' ]= state_level['GENERAL Covered Population 2012']/(state_level['SC Covered Population 2012']+state_level['ST Covered Population 2012']+state_level['GENERAL Covered Population 2012'])
state_level.fillna(0,inplace= True)

district_level['Fraction of SC Covered Population 2009']=district_level['SC Covered Population 2009']/district_level['SC Current Population 2009']
district_level['Fraction of ST Covered Population 2009']=district_level['ST Covered Population 2009']/district_level['ST Current Population 2009']
district_level['Fraction of GENERAL Covered Population 2009']=district_level['GENERAL Covered Population 2009']/district_level['GENERAL Current Population 2009']
district_level['Fraction of SC/Total Population covered 2009' ]= district_level['SC Covered Population 2009']/(district_level['SC Covered Population 2009']+district_level['ST Covered Population 2009']+district_level['GENERAL Covered Population 2009'])
district_level['Fraction of ST/Total Population covered 2009' ]= district_level['ST Covered Population 2009']/(district_level['SC Covered Population 2009']+district_level['ST Covered Population 2009']+district_level['GENERAL Covered Population 2009'])
district_level['Fraction of GENERAL/Total Population covered 2009' ]= district_level['GENERAL Covered Population 2009']/(district_level['SC Covered Population 2009']+district_level['ST Covered Population 2009']+district_level['GENERAL Covered Population 2009'])
district_level['Fraction of SC Covered Population 2010']=district_level['SC Covered Population 2010']/district_level['SC Current Population 2010']
district_level['Fraction of ST Covered Population 2010']=district_level['ST Covered Population 2010']/district_level['ST Current Population 2010']
district_level['Fraction of GENERAL Covered Population 2010']=district_level['GENERAL Covered Population 2010']/district_level['GENERAL Current Population 2010']
district_level['Fraction of SC/Total Population covered 2010' ]= district_level['SC Covered Population 2010']/(district_level['SC Covered Population 2010']+district_level['ST Covered Population 2010']+district_level['GENERAL Covered Population 2010'])
district_level['Fraction of ST/Total Population covered 2010' ]= district_level['ST Covered Population 2010']/(district_level['SC Covered Population 2010']+district_level['ST Covered Population 2010']+district_level['GENERAL Covered Population 2010'])
district_level['Fraction of GENERAL/Total Population covered 2010' ]= district_level['GENERAL Covered Population 2010']/(district_level['SC Covered Population 2010']+district_level['ST Covered Population 2010']+district_level['GENERAL Covered Population 2010'])
district_level['Fraction of SC Covered Population 2011']=district_level['SC Covered Population 2011']/district_level['SC Current Population 2011']
district_level['Fraction of ST Covered Population 2011']=district_level['ST Covered Population 2011']/district_level['ST Current Population 2011']
district_level['Fraction of GENERAL Covered Population 2011']=district_level['GENERAL Covered Population 2011']/district_level['GENERAL Current Population 2012']
district_level['Fraction of SC/Total Population covered 2011' ]= district_level['SC Covered Population 2011']/(district_level['SC Covered Population 2011']+district_level['ST Covered Population 2011']+district_level['GENERAL Covered Population 2011'])
district_level['Fraction of ST/Total Population covered 2011' ]= district_level['ST Covered Population 2011']/(district_level['SC Covered Population 2011']+district_level['ST Covered Population 2011']+district_level['GENERAL Covered Population 2011'])
district_level['Fraction of GENERAL/Total Population covered 2011' ]= district_level['GENERAL Covered Population 2011']/(district_level['SC Covered Population 2011']+district_level['ST Covered Population 2011']+district_level['GENERAL Covered Population 2011'])
district_level['Fraction of SC Covered Population 2012']=district_level['SC Covered Population 2012']/district_level['SC Current Population 2012']
district_level['Fraction of ST Covered Population 2012']=district_level['ST Covered Population 2012']/district_level['ST Current Population 2012']
district_level['Fraction of GENERAL Covered Population 2012']=district_level['GENERAL Covered Population 2012']/district_level['GENERAL Current Population 2012']
district_level['Fraction of SC/Total Population covered 2012' ]= district_level['SC Covered Population 2012']/(district_level['SC Covered Population 2012']+district_level['ST Covered Population 2012']+district_level['GENERAL Covered Population 2012'])
district_level['Fraction of ST/Total Population covered 2012' ]= district_level['ST Covered Population 2012']/(district_level['SC Covered Population 2012']+district_level['ST Covered Population 2012']+district_level['GENERAL Covered Population 2012'])
district_level['Fraction of GENERAL/Total Population covered 2012' ]= district_level['GENERAL Covered Population 2012']/(district_level['SC Covered Population 2012']+district_level['ST Covered Population 2012']+district_level['GENERAL Covered Population 2012'])
district_level.fillna(0,inplace= True)

block_level['Fraction of SC Covered Population 2009']=block_level['SC Covered Population 2009']/block_level['SC Current Population 2009']
block_level['Fraction of ST Covered Population 2009']=block_level['ST Covered Population 2009']/block_level['ST Current Population 2009']
block_level['Fraction of GENERAL Covered Population 2009']=block_level['GENERAL Covered Population 2009']/block_level['GENERAL Current Population 2009']
block_level['Fraction of SC/Total Population covered 2009' ]= block_level['SC Covered Population 2009']/(block_level['SC Covered Population 2009']+block_level['ST Covered Population 2009']+block_level['GENERAL Covered Population 2009'])
block_level['Fraction of ST/Total Population covered 2009' ]= block_level['ST Covered Population 2009']/(block_level['SC Covered Population 2009']+block_level['ST Covered Population 2009']+block_level['GENERAL Covered Population 2009'])
block_level['Fraction of GENERAL/Total Population covered 2009' ]= block_level['GENERAL Covered Population 2009']/(block_level['SC Covered Population 2009']+block_level['ST Covered Population 2009']+block_level['GENERAL Covered Population 2009'])
block_level['Fraction of SC Covered Population 2010']=block_level['SC Covered Population 2010']/block_level['SC Current Population 2010']
block_level['Fraction of ST Covered Population 2010']=block_level['ST Covered Population 2010']/block_level['ST Current Population 2010']
block_level['Fraction of GENERAL Covered Population 2010']=block_level['GENERAL Covered Population 2010']/block_level['GENERAL Current Population 2010']
block_level['Fraction of SC/Total Population covered 2010' ]= block_level['SC Covered Population 2010']/(block_level['SC Covered Population 2010']+block_level['ST Covered Population 2010']+block_level['GENERAL Covered Population 2010'])
block_level['Fraction of ST/Total Population covered 2010' ]= block_level['ST Covered Population 2010']/(block_level['SC Covered Population 2010']+block_level['ST Covered Population 2010']+block_level['GENERAL Covered Population 2010'])
block_level['Fraction of GENERAL/Total Population covered 2010' ]= block_level['GENERAL Covered Population 2010']/(block_level['SC Covered Population 2010']+block_level['ST Covered Population 2010']+block_level['GENERAL Covered Population 2010'])
block_level['Fraction of SC Covered Population 2011']=block_level['SC Covered Population 2011']/block_level['SC Current Population 2011']
block_level['Fraction of ST Covered Population 2011']=block_level['ST Covered Population 2011']/block_level['ST Current Population 2011']
block_level['Fraction of GENERAL Covered Population 2011']=block_level['GENERAL Covered Population 2011']/block_level['GENERAL Current Population 2012']
block_level['Fraction of SC/Total Population covered 2011' ]= block_level['SC Covered Population 2011']/(block_level['SC Covered Population 2011']+block_level['ST Covered Population 2011']+block_level['GENERAL Covered Population 2011'])
block_level['Fraction of ST/Total Population covered 2011' ]= block_level['ST Covered Population 2011']/(block_level['SC Covered Population 2011']+block_level['ST Covered Population 2011']+block_level['GENERAL Covered Population 2011'])
block_level['Fraction of GENERAL/Total Population covered 2011' ]= block_level['GENERAL Covered Population 2011']/(block_level['SC Covered Population 2011']+block_level['ST Covered Population 2011']+block_level['GENERAL Covered Population 2011'])
block_level['Fraction of SC Covered Population 2012']=block_level['SC Covered Population 2012']/block_level['SC Current Population 2012']
block_level['Fraction of ST Covered Population 2012']=block_level['ST Covered Population 2012']/block_level['ST Current Population 2012']
block_level['Fraction of GENERAL Covered Population 2012']=block_level['GENERAL Covered Population 2012']/block_level['GENERAL Current Population 2012']
block_level['Fraction of SC/Total Population covered 2012' ]= block_level['SC Covered Population 2012']/(block_level['SC Covered Population 2012']+block_level['ST Covered Population 2012']+block_level['GENERAL Covered Population 2012'])
block_level['Fraction of ST/Total Population covered 2012' ]= block_level['ST Covered Population 2012']/(block_level['SC Covered Population 2012']+block_level['ST Covered Population 2012']+block_level['GENERAL Covered Population 2012'])
block_level['Fraction of GENERAL/Total Population covered 2012' ]= block_level['GENERAL Covered Population 2012']/(block_level['SC Covered Population 2012']+block_level['ST Covered Population 2012']+block_level['GENERAL Covered Population 2012'])
block_level.fillna(0,inplace= True)

panchayat_level['Fraction of SC Covered Population 2009']=panchayat_level['SC Covered Population 2009']/panchayat_level['SC Current Population 2009']
panchayat_level['Fraction of ST Covered Population 2009']=panchayat_level['ST Covered Population 2009']/panchayat_level['ST Current Population 2009']
panchayat_level['Fraction of GENERAL Covered Population 2009']=panchayat_level['GENERAL Covered Population 2009']/panchayat_level['GENERAL Current Population 2009']
panchayat_level['Fraction of SC/Total Population covered 2009' ]= panchayat_level['SC Covered Population 2009']/(panchayat_level['SC Covered Population 2009']+panchayat_level['ST Covered Population 2009']+panchayat_level['GENERAL Covered Population 2009'])
panchayat_level['Fraction of ST/Total Population covered 2009' ]= panchayat_level['ST Covered Population 2009']/(panchayat_level['SC Covered Population 2009']+panchayat_level['ST Covered Population 2009']+panchayat_level['GENERAL Covered Population 2009'])
panchayat_level['Fraction of GENERAL/Total Population covered 2009' ]= panchayat_level['GENERAL Covered Population 2009']/(panchayat_level['SC Covered Population 2009']+panchayat_level['ST Covered Population 2009']+panchayat_level['GENERAL Covered Population 2009'])
panchayat_level['Fraction of SC Covered Population 2010']=panchayat_level['SC Covered Population 2010']/panchayat_level['SC Current Population 2010']
panchayat_level['Fraction of ST Covered Population 2010']=panchayat_level['ST Covered Population 2010']/panchayat_level['ST Current Population 2010']
panchayat_level['Fraction of GENERAL Covered Population 2010']=panchayat_level['GENERAL Covered Population 2010']/panchayat_level['GENERAL Current Population 2010']
panchayat_level['Fraction of SC/Total Population covered 2010' ]= panchayat_level['SC Covered Population 2010']/(panchayat_level['SC Covered Population 2010']+panchayat_level['ST Covered Population 2010']+panchayat_level['GENERAL Covered Population 2010'])
panchayat_level['Fraction of ST/Total Population covered 2010' ]= panchayat_level['ST Covered Population 2010']/(panchayat_level['SC Covered Population 2010']+panchayat_level['ST Covered Population 2010']+panchayat_level['GENERAL Covered Population 2010'])
panchayat_level['Fraction of GENERAL/Total Population covered 2010' ]= panchayat_level['GENERAL Covered Population 2010']/(panchayat_level['SC Covered Population 2010']+panchayat_level['ST Covered Population 2010']+panchayat_level['GENERAL Covered Population 2010'])
panchayat_level['Fraction of SC Covered Population 2011']=panchayat_level['SC Covered Population 2011']/panchayat_level['SC Current Population 2011']
panchayat_level['Fraction of ST Covered Population 2011']=panchayat_level['ST Covered Population 2011']/panchayat_level['ST Current Population 2011']
panchayat_level['Fraction of GENERAL Covered Population 2011']=panchayat_level['GENERAL Covered Population 2011']/panchayat_level['GENERAL Current Population 2012']
panchayat_level['Fraction of SC/Total Population covered 2011' ]= panchayat_level['SC Covered Population 2011']/(panchayat_level['SC Covered Population 2011']+panchayat_level['ST Covered Population 2011']+panchayat_level['GENERAL Covered Population 2011'])
panchayat_level['Fraction of ST/Total Population covered 2011' ]= panchayat_level['ST Covered Population 2011']/(panchayat_level['SC Covered Population 2011']+panchayat_level['ST Covered Population 2011']+panchayat_level['GENERAL Covered Population 2011'])
panchayat_level['Fraction of GENERAL/Total Population covered 2011' ]= panchayat_level['GENERAL Covered Population 2011']/(panchayat_level['SC Covered Population 2011']+panchayat_level['ST Covered Population 2011']+panchayat_level['GENERAL Covered Population 2011'])
panchayat_level['Fraction of SC Covered Population 2012']=panchayat_level['SC Covered Population 2012']/panchayat_level['SC Current Population 2012']
panchayat_level['Fraction of ST Covered Population 2012']=panchayat_level['ST Covered Population 2012']/panchayat_level['ST Current Population 2012']
panchayat_level['Fraction of GENERAL Covered Population 2012']=panchayat_level['GENERAL Covered Population 2012']/panchayat_level['GENERAL Current Population 2012']
panchayat_level['Fraction of SC/Total Population covered 2012' ]= panchayat_level['SC Covered Population 2012']/(panchayat_level['SC Covered Population 2012']+panchayat_level['ST Covered Population 2012']+panchayat_level['GENERAL Covered Population 2012'])
panchayat_level['Fraction of ST/Total Population covered 2012' ]= panchayat_level['ST Covered Population 2012']/(panchayat_level['SC Covered Population 2012']+panchayat_level['ST Covered Population 2012']+panchayat_level['GENERAL Covered Population 2012'])
panchayat_level['Fraction of GENERAL/Total Population covered 2012' ]= panchayat_level['GENERAL Covered Population 2012']/(panchayat_level['SC Covered Population 2012']+panchayat_level['ST Covered Population 2012']+panchayat_level['GENERAL Covered Population 2012'])
panchayat_level.fillna(0,inplace= True)

village_level['Fraction of SC Covered Population 2009']=village_level['SC Covered Population 2009']/village_level['SC Current Population 2009']
village_level['Fraction of ST Covered Population 2009']=village_level['ST Covered Population 2009']/village_level['ST Current Population 2009']
village_level['Fraction of GENERAL Covered Population 2009']=village_level['GENERAL Covered Population 2009']/village_level['GENERAL Current Population 2009']
village_level['Fraction of SC/Total Population covered 2009' ]= village_level['SC Covered Population 2009']/(village_level['SC Covered Population 2009']+village_level['ST Covered Population 2009']+village_level['GENERAL Covered Population 2009'])
village_level['Fraction of ST/Total Population covered 2009' ]= village_level['ST Covered Population 2009']/(village_level['SC Covered Population 2009']+village_level['ST Covered Population 2009']+village_level['GENERAL Covered Population 2009'])
village_level['Fraction of GENERAL/Total Population covered 2009' ]= village_level['GENERAL Covered Population 2009']/(village_level['SC Covered Population 2009']+village_level['ST Covered Population 2009']+village_level['GENERAL Covered Population 2009'])
village_level['Fraction of SC Covered Population 2010']=village_level['SC Covered Population 2010']/village_level['SC Current Population 2010']
village_level['Fraction of ST Covered Population 2010']=village_level['ST Covered Population 2010']/village_level['ST Current Population 2010']
village_level['Fraction of GENERAL Covered Population 2010']=village_level['GENERAL Covered Population 2010']/village_level['GENERAL Current Population 2010']
village_level['Fraction of SC/Total Population covered 2010' ]= village_level['SC Covered Population 2010']/(village_level['SC Covered Population 2010']+village_level['ST Covered Population 2010']+village_level['GENERAL Covered Population 2010'])
village_level['Fraction of ST/Total Population covered 2010' ]= village_level['ST Covered Population 2010']/(village_level['SC Covered Population 2010']+village_level['ST Covered Population 2010']+village_level['GENERAL Covered Population 2010'])
village_level['Fraction of GENERAL/Total Population covered 2010' ]= village_level['GENERAL Covered Population 2010']/(village_level['SC Covered Population 2010']+village_level['ST Covered Population 2010']+village_level['GENERAL Covered Population 2010'])
village_level['Fraction of SC Covered Population 2011']=village_level['SC Covered Population 2011']/village_level['SC Current Population 2011']
village_level['Fraction of ST Covered Population 2011']=village_level['ST Covered Population 2011']/village_level['ST Current Population 2011']
village_level['Fraction of GENERAL Covered Population 2011']=village_level['GENERAL Covered Population 2011']/village_level['GENERAL Current Population 2012']
village_level['Fraction of SC/Total Population covered 2011' ]= village_level['SC Covered Population 2011']/(village_level['SC Covered Population 2011']+village_level['ST Covered Population 2011']+village_level['GENERAL Covered Population 2011'])
village_level['Fraction of ST/Total Population covered 2011' ]= village_level['ST Covered Population 2011']/(village_level['SC Covered Population 2011']+village_level['ST Covered Population 2011']+village_level['GENERAL Covered Population 2011'])
village_level['Fraction of GENERAL/Total Population covered 2011' ]= village_level['GENERAL Covered Population 2011']/(village_level['SC Covered Population 2011']+village_level['ST Covered Population 2011']+village_level['GENERAL Covered Population 2011'])
village_level['Fraction of SC Covered Population 2012']=village_level['SC Covered Population 2012']/village_level['SC Current Population 2012']
village_level['Fraction of ST Covered Population 2012']=village_level['ST Covered Population 2012']/village_level['ST Current Population 2012']
village_level['Fraction of GENERAL Covered Population 2012']=village_level['GENERAL Covered Population 2012']/village_level['GENERAL Current Population 2012']
village_level['Fraction of SC/Total Population covered 2012' ]= village_level['SC Covered Population 2012']/(village_level['SC Covered Population 2012']+village_level['ST Covered Population 2012']+village_level['GENERAL Covered Population 2012'])
village_level['Fraction of ST/Total Population covered 2012' ]= village_level['ST Covered Population 2012']/(village_level['SC Covered Population 2012']+village_level['ST Covered Population 2012']+village_level['GENERAL Covered Population 2012'])
village_level['Fraction of GENERAL/Total Population covered 2012' ]= village_level['GENERAL Covered Population 2012']/(village_level['SC Covered Population 2012']+village_level['ST Covered Population 2012']+village_level['GENERAL Covered Population 2012'])
village_level.fillna(0,inplace= True)

state_level.to_csv('../Data/state_level_aggregation.csv')
district_level.to_csv('../Data/district_level_aggregation.csv')

# %%
#Plotting the national level 
working = pd.read_csv('state_level_aggregation.csv')
state_level = working
state_cluster = pd.DataFrame();
state_cluster['SC']=state_level['Fraction of SC Covered Population 2009']
state_cluster['ST']=state_level['Fraction of ST Covered Population 2009']
state_cluster['GENERAL']=state_level['Fraction of GENERAL Covered Population 2009']
state_cluster.to_csv('cluster.csv')
X = state_cluster.values

# %%
#training for dbscan
labels = MyDBSCAN(X,eps = .115, MinPts = 2)
Counter(labels)

state_level['label']=labels

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)


c1=[]
c2=[]
c3=[]
c4=[]

r,c= state_cluster.shape
for x in range(0,r):
    if(labels[x]==1):
        c1.append(X[x])
    elif(labels[x]==2):
        c2.append(X[x])
    elif(labels[x]==3):
        c3.append(X[x])
    elif(labels[x]==-1):
        c4.append(X[x])

put1 = pd.DataFrame(c1,columns=['one','two','three'])
put2 = pd.DataFrame(c2,columns=['one','two','three'])
put3 = pd.DataFrame(c3,columns=['one','two','three'])
put4 = pd.DataFrame(c4,columns=['one','two','three'])

# %%
#plotting the clusters formed
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(0,1)
ax.set_ylim(0,1)
ax.set_zlim(0,1)
fig.suptitle('NATIONAL LEVEL',fontsize=20)
ax.set_xlabel('SC',fontsize=10)
ax.set_ylabel('ST',fontsize=10)
ax.set_zlabel('GENERAL',fontsize=10)

# %%
#plt.gca().invert_yaxis()
ax.plot(put1['one'],put1['two'],put1['three'], linestyle='None', marker='o', markersize=5, color='blue',label='Cluster 1')
ax.plot(put2['one'],put2['two'],put2['three'], linestyle='None', marker='o', markersize=5, color='red',label='Cluster 2')
ax.plot(put3['one'],put3['two'],put3['three'], linestyle='None', marker='o', markersize=5, color='green',label='Cluster 3')
ax.plot(put4['one'],put4['two'],put4['three'], linestyle='None', marker='o', markersize=5, color='black',label='outlier')
pl.legend(loc=1,prop={'size': 12})
fig.set_size_inches(10, 10)
plt.savefig('../Plots/state level clusters')
fig.show()

# %%
#plotting forvarious staes.
checking=pd.read_csv('district_level_aggregation.csv')
district_level=checking
district_temp=district_level

# %%
#enter the state name here 
filter = district_level['State Name']=="ASSAM"
district_temp.where(filter,inplace= True)
district_temp.fillna(-1,inplace= True)
indexNames = district_temp[ district_temp['SC Current Population 2009'] == -1 ].index
district_temp.drop(indexNames , inplace=True)

# %%
district_temp.to_csv('../Data/district_per_state.csv')

# %%
district_cluster = pd.DataFrame();
district_cluster['SC']=district_temp['Fraction of SC Covered Population 2009']
district_cluster['ST']=district_temp['Fraction of ST Covered Population 2009']
district_cluster['GENERAL']=district_temp['Fraction of GENERAL Covered Population 2009']
X = district_cluster.values

# %%
#using dbscan
labels = MyDBSCAN(X,eps = .1, MinPts = 2)
Counter(labels)

# %%
#plotting initial scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(0,1)
ax.set_ylim(0,1)
ax.set_zlim(0,1)
fig.suptitle('ASSAM DISTRICT INITIAL')
ax.set_xlabel('SC')
ax.set_ylabel('ST')
ax.set_zlabel('GENERAL')
ax.plot(district_temp['Fraction of SC Covered Population 2009'],district_temp['Fraction of ST Covered Population 2009'],district_temp['Fraction of GENERAL Covered Population 2009'], linestyle='None', marker='o', markersize=12, color='blue',label='class 0')
fig.set_size_inches(10, 10)
plt.savefig('../Plots/ASSAM initial')
fig.show()

# %%
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

district_temp['label']=labels
district_temp.to_csv('../Data/district_per_state.csv')

c1=[]
c2=[]
c3=[]
c4=[]
c5=[]

r,c= district_cluster.shape
for x in range(0,r):
    if(labels[x]==1):
        c1.append(X[x])
    elif(labels[x]==2):
        c2.append(X[x])
    elif(labels[x]==3):
        c3.append(X[x])
    elif(labels[x]==-1):
        c4.append(X[x])
    elif(labels[x]==4):
        c5.append(X[x])


put1 = pd.DataFrame(c1,columns=['one','two','three'])
put2 = pd.DataFrame(c2,columns=['one','two','three'])
put3 = pd.DataFrame(c3,columns=['one','two','three'])
put4 = pd.DataFrame(c4,columns=['one','two','three'])
put5 = pd.DataFrame(c5,columns=['one','two','three'])

# %%
#plotting dbscan cluster plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(0,1)
ax.set_ylim(0,1)
ax.set_zlim(0,1)
fig.suptitle('ASSAM',fontsize=20)
ax.set_xlabel('SC',fontsize=10)
ax.set_ylabel('ST',fontsize=10)
ax.set_zlabel('GENERAL',fontsize=10)

# %%
#plt.gca().invert_yaxis()
ax.plot(put1['one'],put1['two'],put1['three'], linestyle='None', marker='o', markersize=7, color='blue',label='Cluster 1')
ax.plot(put2['one'],put2['two'],put2['three'], linestyle='None', marker='o', markersize=7, color='red',label='Cluster 2')
ax.plot(put3['one'],put3['two'],put3['three'], linestyle='None', marker='o', markersize=7, color='green',label='Cluster 3')
ax.plot(put5['one'],put5['two'],put5['three'], linestyle='None', marker='o', markersize=7, color='pink',label='Cluster 4')
ax.plot(put4['one'],put4['two'],put4['three'], linestyle='None', marker='o', markersize=7, color='black',label='outlier')
pl.legend(loc=2,prop={'size': 12})
fig.set_size_inches(10, 10)
plt.savefig('../Plots/ASSAM state cluster')
fig.show()

# %%
#drawing some more attributes at national level
national = pd.DataFrame();
national['State Name']=state_level['State Name']
national['SC Covered Population'] = state_level['SC Covered Population 2009']
national['ST Covered Population'] = state_level['ST Covered Population 2009']
national['GENERAL Covered Population'] = state_level['GENERAL Covered Population 2009']
national['SC Current Population'] = state_level['SC Current Population 2009']
national['ST Current Population'] = state_level['ST Current Population 2009']
national['GENERAL Current Population'] = state_level['GENERAL Current Population 2009']
national['Total Covered Population'] = national['SC Covered Population']+national['ST Covered Population']+national['GENERAL Covered Population']
national['Total Current Population'] = national['SC Current Population']+national['ST Current Population']+national['GENERAL Current Population']

# %%
N,c=national.shape
sum1=0
for x in range(0,N):
    sum1 = sum1 + national.iloc[x]['Total Covered Population']

national['Percentage out of Total Covered Population']= national['Total Covered Population']*100/sum1
national.to_csv('national.csv')

N,c=national.shape
sum1=0
for x in range(0,N):
    sum1 = sum1 + national.iloc[x]['Total Current Population']

national['Percentage  out of Total Current Population']= national['Total Current Population']*100/sum1
national.to_csv('../Data/national.csv')
